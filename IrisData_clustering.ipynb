# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# K-Means Clustering
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Load the Iris dataset
iris = load_iris()

# %%
df=pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [149 rows x 4 columns]

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %% [raw]
# KMeans Clustering
# Brief Description:
#
# KMeans is a centroid-based clustering algorithm.
# It works by initializing cluster centroids, assigning points to the nearest centroid, and iteratively updating centroids until convergence.
# Suitable for compact and spherical clusters.
# Why KMeans for Iris Dataset?:
#
# The Iris dataset is relatively small and features are numerical, making it a good fit for KMeans.
# The dataset is known to have three well-defined clusters, matching the algorithm's assumptions.
# Implementation:
#
# Import KMeans from sklearn.cluster.
# Apply the algorithm and visualize results using scatter plots.

# %%
inertia = []
k_values = range(1, 11)  # Test cluster numbers from 1 to 10

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df.drop(columns=['KMeans_Cluster', 'Hierarchical_Cluster'], errors='ignore'))
    inertia.append(kmeans.inertia_)

# Plot the Elbow Curve
plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker='o', linestyle='--')
plt.title('Elbow Plot for KMeans')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.xticks(k_values)
plt.vlines(x=2,ymin=0,ymax=600,linestyles='--')
plt.text(x=3.5,y=400,s='2 clusters seem optimal choice \nfrom the elbow position',
             fontsize=25,fontdict={'family':'Times New Roman'})
plt.grid()
plt.show()

# %%
max_clusters=10
silhouette_scores = []

# %%
#Elbow method
for k in range(2, max_clusters + 1):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled)
    score = silhouette_score(df_scaled, kmeans.labels_)
    silhouette_scores.append(score)

# %%
# Find optimal number of clusters
optimal_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %%
# Final K-Means with optimal clusters
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
df['KMeans_Cluster'] = kmeans.fit_predict(df_scaled)

# %%
df['KMeans_Cluster'].unique()
# Out:
# array([1, 0])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(range(2, max_clusters + 1), silhouette_scores, marker='o', linestyle='--')
plt.title('Silhouette Scores for Different Numbers of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.grid()
plt.show()

# %%
# Visualize the clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='sepal length (cm)', y='sepal width (cm)', hue='KMeans_Cluster', palette='viridis')
plt.title('KMeans Clustering on Iris Dataset')
plt.show()

# %% [raw]
# highest score is obtained for 2 clusters

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    KMeans_Cluster
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# Hierarchical Clustering (4 marks)
# Brief Description:
#
# Hierarchical clustering builds a tree-like structure of clusters.
# Two approaches:
# Agglomerative (bottom-up, merging clusters).
# Divisive (top-down, splitting clusters).
# Visualized using a dendrogram.
# Why Hierarchical Clustering for Iris Dataset?:
#
# Suitable for small datasets.
# Provides a hierarchical structure, allowing for exploration at various cluster levels.
# Doesn't require pre-specifying the number of clusters.
# Implementation:
#
# Import AgglomerativeClustering from sklearn.cluster and scipy.cluster.hierarchy for visualization.

# %%
plt.figure(figsize=(8, 6))
linkage_matrix = linkage(df.drop(columns=['KMeans_Cluster']), method='ward')
dendrogram(linkage_matrix)
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %% [markdown]
# 3 clusters seems optimum from dendogram

# %%
hc=AgglomerativeClustering(n_clusters=3,linkage='ward')
df['Hierarchical_Cluster'] = hc.fit_predict(df_scaled)

# %%
# Visualize clusters
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='sepal length (cm)', y='sepal width (cm)', hue='Hierarchical_Cluster')
plt.title('Hierarchical Clustering on Iris Dataset')
plt.show()
